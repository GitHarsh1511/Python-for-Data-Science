# %%
import pandas
df1 = pandas.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")
df1.head()
# df1.tail()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
import numpy as np
import seaborn as sns
sns.set( style = "white" )
rs = np.random.RandomState(10)
d = rs.normal( size = 50 )
sns.distplot(d, kde = True, color = "g")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_84412\3319129703.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d, kde = True, color = "g")
# <Axes: ylabel='Density'>

# %%
import seaborn as sns
import pandas as pd  # It's a good practice to use 'pd' as the alias for pandas

# loading csv
df2 = pd.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")

# plotting lineplot
sns.lineplot(x='Age', y='Weight', data=df2)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
import seaborn
import pandas

# load csv
df3 = pandas.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")

# plotting
sns.scatterplot(x='Age', y='Weight', data=df3)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
import seaborn as sns
import pandas

# read csv and plotting
df4 = pandas.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")
sns.boxplot( df4['Age'] )
# Out:
# <Axes: ylabel='Age'>

# %%
import seaborn
seaborn.set(style = 'whitegrid')
# read csv and plot
df5 = pandas.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")
seaborn.barplot(x = df5["Age"] )
# Out:
# <Axes: xlabel='Age'>

# %%
import seaborn
seaborn.set(style = 'whitegrid')
# read csv and plot
df6 = pandas.read_csv("D:\\College\\Semester 5\\PDS\\CSV\\nba.csv")
seaborn.barplot( x ="Age", y ="Weight", data = df6 )
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>
