# %%
import pandas 

mydataset={'cars':["BMW","VOLVO","FORD","AUDI","THAR"],'passings':[3,7,2,9,8]}
myvar=pandas.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  VOLVO         7
# 2   FORD         2
# 3   AUDI         9
# 4   THAR         8

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
import pandas as pd 
data = {"calories": [420, 380, 390],
        "duration": [50, 40, 45]
       }
#load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
import pandas as pd 
data = {"calories": [420, 380, 390],
        "duration": [50, 40, 45]
       }
#load data into a DataFrame object:
df = pd.DataFrame(data,index=["day1","day2","day3"])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
import pandas as pd
df = pd.read_csv("D:\\College\\Semester 5\\PDS\\Python Lab4\\HeartAttack.csv")
print(df)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
print(df.head())
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
print(df.tail())
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  output
# 0     63    1   3     145   233    1        0       150     0      2.3    0    0      1       1
# 1     37    1   2     130   250    0        1       187     0      3.5    0    0      2       1
# 2     41    0   1     130   204    0        0       172     0      1.4    2    0      2       1
# 3     56    1   1     120   236    0        1       178     0      0.8    2    0      2       1
# 4     57    0   0     120   354    0        1       163     1      0.6    2    0      2       1
# 5     57    1   0     140   192    0        1       148     0      0.4    1    0      1       1
# 6     56    0   1     140   294    0        0       153     0      1.3    1    0      2       1
# 7     44    1   1     120   263    0        1       173     0      0.0    2    0      3       1
# 8     52    1   2     172   199    1        1       162     0      0.5    2    0      3       1
# ...

# %%
df.dropna(inplace=True)
print(df.to_string())
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  output
# 0     63    1   3     145   233    1        0       150     0      2.3    0    0      1       1
# 1     37    1   2     130   250    0        1       187     0      3.5    0    0      2       1
# 2     41    0   1     130   204    0        0       172     0      1.4    2    0      2       1
# 3     56    1   1     120   236    0        1       178     0      0.8    2    0      2       1
# 4     57    0   0     120   354    0        1       163     1      0.6    2    0      2       1
# 5     57    1   0     140   192    0        1       148     0      0.4    1    0      1       1
# 6     56    0   1     140   294    0        0       153     0      1.3    1    0      2       1
# 7     44    1   1     120   263    0        1       173     0      0.0    2    0      3       1
# 8     52    1   2     172   199    1        1       162     0      0.5    2    0      3       1
# ...

# %%
df.fillna(130,inplace=True)
print(df.to_string())
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  output
# 0     63    1   3     145   233    1        0       150     0      2.3    0    0      1       1
# 1     37    1   2     130   250    0        1       187     0      3.5    0    0      2       1
# 2     41    0   1     130   204    0        0       172     0      1.4    2    0      2       1
# 3     56    1   1     120   236    0        1       178     0      0.8    2    0      2       1
# 4     57    0   0     120   354    0        1       163     1      0.6    2    0      2       1
# 5     57    1   0     140   192    0        1       148     0      0.4    1    0      1       1
# 6     56    0   1     140   294    0        0       153     0      1.3    1    0      2       1
# 7     44    1   1     120   263    0        1       173     0      0.0    2    0      3       1
# 8     52    1   2     172   199    1        1       162     0      0.5    2    0      3       1
# ...

# %%
import pandas as pd
df = pd.read_csv("D:\\College\\Semester 5\\PDS\\Python Lab4\\HeartAttack.csv")
df.drop_duplicates(inplace = True) 
print(df.to_string())
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  output
# 0     63    1   3     145   233    1        0       150     0      2.3    0    0      1       1
# 1     37    1   2     130   250    0        1       187     0      3.5    0    0      2       1
# 2     41    0   1     130   204    0        0       172     0      1.4    2    0      2       1
# 3     56    1   1     120   236    0        1       178     0      0.8    2    0      2       1
# 4     57    0   0     120   354    0        1       163     1      0.6    2    0      2       1
# 5     57    1   0     140   192    0        1       148     0      0.4    1    0      1       1
# 6     56    0   1     140   294    0        0       153     0      1.3    1    0      2       1
# 7     44    1   1     120   263    0        1       173     0      0.0    2    0      3       1
# 8     52    1   2     172   199    1        1       162     0      0.5    2    0      3       1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("D:\\College\\Semester 5\\PDS\\Python Lab4\\HeartAttack.csv")
df.plot()
plt.show()

# %%
import pandas as pd
s = pd.Series([1, 3, 5, 7, 9, 11]) 
print(s)
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int64

# %%
import pandas as pd 
s = pd.Series([1, 3, 5, 7, 9, 11]) 
print("S[0] = ", s[0])
b = s[0] + s[1]
print("Sum = ", b)
# Out:
# S[0] =  1
# Sum =  4

# %%
import pandas as pd 
s = pd.Series([1, 3, 5, 7, 9, 11], dtype='str') 
print("S[0] = ", s[0])
b = s[0] + s[1]
print("Sum = ", b)
# Out:
# S[0] =  1
# Sum =  13

# %%
import numpy as np 
import pandas as pd 
i = ['name','address','phone','email','website'] 
d = ['adit','an',123,'d@d.com','adit.edu.in'] 
s = pd.Series(data=d,index=i) 
print(s)
# Out:
# name              adit
# address             an
# phone              123
# email          d@d.com
# website    adit.edu.in
# dtype: object

# %%
import numpy as np 
import pandas as pd 
dates = pd.to_datetime("27th of July, 2020") 
i = dates + pd.to_timedelta(np.arange(5), unit='D') 
d = [50,53,25,70,60] 
time_series = pd.Series(data=d,index=i)
print(time_series)
# Out:
# 2020-07-27    50
# 2020-07-28    53
# 2020-07-29    25
# 2020-07-30    70
# 2020-07-31    60
# dtype: int64

# %%
import numpy as np 
import pandas as pd
randArr = np.random.randint(0,100,20).reshape(5,4)
df = pd.DataFrame(randArr,np.arange(101,106,1),['PDS','Algo','SE','INS'])
print(df['PDS'])
# Out:
# 101    70
# 102     1
# 103    93
# 104     4
# 105    72
# Name: PDS, dtype: int32

# %%
print(df[['PDS', 'SE']])
# Out:
#      PDS  SE
# 101   70  19
# 102    1  50
# 103   93  68
# 104    4  96
# 105   72  89

# %%
print(df.loc[101]) # using labels
#OR
print(df.iloc[0]) # using zero based index
# Out:
# PDS     70
# Algo    15
# SE      19
# INS     59
# Name: 101, dtype: int32
# PDS     70
# Algo    15
# SE      19
# INS     59
# Name: 101, dtype: int32

# %%
print(df.loc[101, 'PDS']) # using labels
# Out:
# 70

# %%
df.drop(103,inplace=True) 
print(df)
# Out:
#      PDS  Algo  SE  INS
# 101   82    17  46   25
# 102   14    55  75   88
# 104   38    35  71   51
# 105   76    92  71   83

# %%
import numpy as np 
import pandas as pd
randArr = np.random.randint(0,100,20).reshape(5,4)
df = pd.DataFrame(randArr,np.arange(101,106,1),['PDS','Algo','SE','INS'])
df['total'] = df['PDS'] + df['Algo'] + df['SE'] + df['INS']
print(df)
# Out:
#      PDS  Algo  SE  INS  total
# 101    8    87  50   42    187
# 102   78    31  62    3    174
# 103   83    63   1   69    216
# 104   54    73  40   54    221
# 105   75    75  15   15    180

# %%
df.drop('total',axis=1,inplace=True) 
print(df)
# Out:
#      PDS  Algo  SE  INS
# 101    8    87  50   42
# 102   78    31  62    3
# 103   83    63   1   69
# 104   54    73  40   54
# 105   75    75  15   15

# %%
print(df.loc[[101,104]], [['PDS','INS']])
# Out:
#      PDS  Algo  SE  INS
# 101    8    87  50   42
# 104   54    73  40   54 [['PDS', 'INS']]

# %%
print(df.loc[:, df.columns != 'Algo' ])
# Out:
#      PDS  SE  INS
# 101    8  50   42
# 102   78  62    3
# 103   83   1   69
# 104   54  40   54
# 105   75  15   15

# %%
import numpy as np 
import pandas as pd
randArr = np.random.randint(0,100,20).reshape(5,4) 
df = pd.DataFrame(randArr,np.arange(101,106,1),['PDS','Algo','SE','INS']) 
print(df)
print(df>50)
# Out:
#      PDS  Algo  SE  INS
# 101   12     4  63   26
# 102    3    24  40   93
# 103   21    26  52   49
# 104   27    31  91   19
# 105   11    70  36   21
#        PDS   Algo     SE    INS
# 101  False  False   True  False
# 102  False  False  False   True
# 103  False  False   True  False
# 104  False  False   True  False
# 105  False   True  False  False

# %%
df.set_index('PDS') #inplace=True
# Out:
#      Algo  SE  INS
# PDS
# 12      4  63   26
# 3      24  40   93
# 21     26  52   49
# 27     31  91   19
# 11     70  36   21

# %%
df.reset_index()
# Out:
#    index  PDS  Algo  SE  INS
# 0    101   12     4  63   26
# 1    102    3    24  40   93
# 2    103   21    26  52   49
# 3    104   27    31  91   19
# 4    105   11    70  36   21

# %%
import pandas as pd
dfMulti = pd.read_csv("D:\\College\\Semester 5\\PDS\\Python Lab4\\HeartAttack.csv")
dfMulti.set_index(['age','sex','cp'],inplace=True) 
print(dfMulti)
# Out:
#             trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age sex cp
# 63  1   3      145   233    1        0       150     0      2.3    0    0
# 37  1   2      130   250    0        1       187     0      3.5    0    0
# 41  0   1      130   204    0        0       172     0      1.4    2    0
# 56  1   1      120   236    0        1       178     0      0.8    2    0
# 57  0   0      120   354    0        1       163     1      0.6    2    0
# ...            ...   ...  ...      ...       ...   ...      ...  ...  ...
#         0      140   241    0        1       123     1      0.2    1    0
# 45  1   3      110   264    0        1       132     0      1.2    1    0
# 68  1   0      144   193    1        1       141     0      3.4    1    2
# 57  1   0      130   131    0        1       115     1      1.2    1    1
#     0   1      130   236    0        0       174     0      0.0    1    1
#
#             thall  output
# age sex cp
# 63  1   3       1       1
# ...

# %%
#print(dfMulti.loc['age'])

# %%
#print(dfMulti.loc[‘MBIT','CE'])

# %%
import pandas as pd
dfMulti = pd.read_csv("D:\\College\\Semester 5\\PDS\\Python Lab4\\HeartAttack.csv",index_col=[0,1,2])
                      #for multi-index in cols we can use header parameter
print(dfMulti)
# Out:
#             trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age sex cp
# 63  1   3      145   233    1        0       150     0      2.3    0    0
# 37  1   2      130   250    0        1       187     0      3.5    0    0
# 41  0   1      130   204    0        0       172     0      1.4    2    0
# 56  1   1      120   236    0        1       178     0      0.8    2    0
# 57  0   0      120   354    0        1       163     1      0.6    2    0
# ...            ...   ...  ...      ...       ...   ...      ...  ...  ...
#         0      140   241    0        1       123     1      0.2    1    0
# 45  1   3      110   264    0        1       132     0      1.2    1    0
# 68  1   0      144   193    1        1       141     0      3.4    1    2
# 57  1   0      130   131    0        1       115     1      1.2    1    1
#     0   1      130   236    0        0       174     0      0.0    1    1
#
#             thall  output
# age sex cp
# 63  1   3       1       1
# ...

# %%
#print(dfMulti.xs('age',axis=0,level='sex'))
